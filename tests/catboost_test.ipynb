# %%
import sys
import pandas as pd
import numpy as np
pd.options.display.max_columns = None

sys.path.append('../')
from modeling import SOTAModels

# %% [markdown]
# # Binary

# %%
# data = pd.read_parquet('/www/dslib/spark_sota_modeling/dataset/home-credit-default-risk/train.parquet')
# data.info(max_cols=1000, show_counts=True)
# data.columns[~np.isfinite(data.values).all(axis=0)].tolist()

# %%
modelling = SOTAModels('home-credit-default-risk.yaml')
trained_models, metrics_results = modelling.train_models()
# Out:
# Splitting data ...
# Data split done: train shape: (184506, 464), test shape: (61503, 464), valid shape: (61502, 464)
# Sampling data ...
# Data sampled: train shape: (29790, 464), valid shape: (61502, 464)
# ----------
# Обучение модели: random_forest на 3 фолдах, тип задачи: binary
# Fold 1: roc_auc: 0.7524
# Fold 2: roc_auc: 0.7522
# Fold 3: roc_auc: 0.7487
# Метрики на тестовых данных (holdout):
#    f1: 0.2688
#    roc_auc: 0.7574
#    recall@k;k=0.1: 0.3295
#    precision@k;k=0.1: 0.2660
#    ap;average=micro: 0.2292
#    ap;average=weighted: 0.2292
#    f1;average=binary: 0.2688
# Calibrating ... done
# Метрики на валидационных данных (out-of-time):
#    f1: 0.0209
#    roc_auc: 0.7534
#    recall@k;k=0.1: 0.3172
#    precision@k;k=0.1: 0.2561
#    ap;average=micro: 0.2175
#    ap;average=weighted: 0.2175
#    f1;average=binary: 0.0209
# Модель random_forest сохранена в /home/gleb/models/20250410_235419_0.7534_random_forest_binary.pickle
#
# ----------
# Обучение модели: catboost на 3 фолдах, тип задачи: binary
# Fold 1: roc_auc: 0.7767
# Fold 2: roc_auc: 0.7758
# Fold 3: roc_auc: 0.7695
# Метрики на тестовых данных (holdout):
#    f1: 0.2840
#    roc_auc: 0.7787
#    recall@k;k=0.1: 0.3654
#    precision@k;k=0.1: 0.2950
#    ap;average=micro: 0.2713
#    ap;average=weighted: 0.2713
#    f1;average=binary: 0.2840
# Calibrating ... done
# Метрики на валидационных данных (out-of-time):
#    f1: 0.0603
#    roc_auc: 0.7754
#    recall@k;k=0.1: 0.3547
#    precision@k;k=0.1: 0.2863
#    ap;average=micro: 0.2555
#    ap;average=weighted: 0.2555
#    f1;average=binary: 0.0603
# Модель catboost сохранена в /home/gleb/models/20250410_235525_0.7754_catboost_binary.pickle
#
# ----------
# Обучение модели: lightgbm на 3 фолдах, тип задачи: binary
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [96]	valid_0's auc: 0.772607
# Fold 1: roc_auc: 0.7726
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [139]	valid_0's auc: 0.773719
# Fold 2: roc_auc: 0.7737
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [118]	valid_0's auc: 0.7662
# Fold 3: roc_auc: 0.7662
# Метрики на тестовых данных (holdout):
#    f1: 0.2832
#    roc_auc: 0.7779
#    recall@k;k=0.1: 0.3656
#    precision@k;k=0.1: 0.2951
#    ap;average=micro: 0.2677
#    ap;average=weighted: 0.2677
#    f1;average=binary: 0.2832
# Calibrating ... done
# Метрики на валидационных данных (out-of-time):
#    f1: 0.0515
#    roc_auc: 0.7765
#    recall@k;k=0.1: 0.3507
#    precision@k;k=0.1: 0.2831
#    ap;average=micro: 0.2546
#    ap;average=weighted: 0.2546
#    f1;average=binary: 0.0515
# Модель lightgbm сохранена в /home/gleb/models/20250410_235538_0.7765_lightgbm_binary.pickle
#
# ----------
# Обучение модели: xgboost на 3 фолдах, тип задачи: binary
# Fold 1: roc_auc: 0.7633
# Fold 2: roc_auc: 0.7637
# Fold 3: roc_auc: 0.7593
# Метрики на тестовых данных (holdout):
#    f1: 0.2791
#    roc_auc: 0.7742
#    recall@k;k=0.1: 0.3541
#    precision@k;k=0.1: 0.2859
#    ap;average=micro: 0.2598
#    ap;average=weighted: 0.2598
#    f1;average=binary: 0.2791
# Calibrating ... done
# Метрики на валидационных данных (out-of-time):
#    f1: 0.0495
#    roc_auc: 0.7724
#    recall@k;k=0.1: 0.3476
#    precision@k;k=0.1: 0.2807
#    ap;average=micro: 0.2525
#    ap;average=weighted: 0.2525
#    f1;average=binary: 0.0495
# Модель xgboost сохранена в /home/gleb/models/20250410_235550_0.7724_xgboost_binary.pickle
#
# Лучшая модель по метрике roc_auc: lightgbm
# Значение метрики: 0.7765371876977212

# %% [markdown]
# # Multi

# %%
# data = pd.read_parquet('/www/dslib/spark_sota_modeling/dataset/forest-cover-type/train.parquet')

# %%
modelling = SOTAModels('forest-cover-type.yaml')
trained_models, metrics_results = modelling.train_models()
# Out:
# Splitting data ...
# Data split done: train shape: (348606, 55), test shape: (116203, 55), valid shape: (116203, 55)
# Sampling data ...
# Data sampled: train shape: (100000, 55), valid shape: (100000, 55)
# ----------
# Обучение модели: random_forest на 3 фолдах, тип задачи: multi
# Fold 1: accuracy: 0.8843
# Fold 2: accuracy: 0.8861
# Fold 3: accuracy: 0.8825
# Метрики на тестовых данных (holdout):
#    accuracy: 0.8847
#    f1;average=weighted: 0.8826
#    ap;average=macro: 0.9160
#    ap;average=weighted: 0.9555
# Метрики на валидационных данных (out-of-time):
#    accuracy: 0.8828
#    f1;average=weighted: 0.8806
#    ap;average=macro: 0.9141
#    ap;average=weighted: 0.9552
# Модель random_forest сохранена в /home/gleb/models/20250410_235658_0.8828_random_forest_multi.pickle
#
# ----------
# Обучение модели: catboost на 3 фолдах, тип задачи: multi
# Fold 1: accuracy: 0.8688
# Fold 2: accuracy: 0.8708
# Fold 3: accuracy: 0.8687
# Метрики на тестовых данных (holdout):
#    accuracy: 0.8697
#    f1;average=weighted: 0.8700
#    ap;average=macro: 0.9145
#    ap;average=weighted: 0.9446
# Метрики на валидационных данных (out-of-time):
#    accuracy: 0.8686
#    f1;average=weighted: 0.8689
#    ap;average=macro: 0.9143
#    ap;average=weighted: 0.9444
# Модель catboost сохранена в /home/gleb/models/20250410_235956_0.8686_catboost_multi.pickle
#
# ----------
# Обучение модели: lightgbm на 3 фолдах, тип задачи: multi
# Fold 1: accuracy: 0.8787
# Fold 2: accuracy: 0.8808
# Fold 3: accuracy: 0.8795
# Метрики на тестовых данных (holdout):
#    accuracy: 0.8815
#    f1;average=weighted: 0.8807
#    ap;average=macro: 0.9225
#    ap;average=weighted: 0.9529
# Метрики на валидационных данных (out-of-time):
#    accuracy: 0.8810
#    f1;average=weighted: 0.8802
#    ap;average=macro: 0.9210
#    ap;average=weighted: 0.9525
# Модель lightgbm сохранена в /home/gleb/models/20250411_000357_0.8810_lightgbm_multi.pickle
#
# ----------
# Обучение модели: xgboost на 3 фолдах, тип задачи: multi
# Fold 1: accuracy: 0.9138
# Fold 2: accuracy: 0.9130
# Fold 3: accuracy: 0.9122
# Метрики на тестовых данных (holdout):
#    accuracy: 0.9161
#    f1;average=weighted: 0.9155
#    ap;average=macro: 0.9469
#    ap;average=weighted: 0.9739
# Метрики на валидационных данных (out-of-time):
#    accuracy: 0.9147
#    f1;average=weighted: 0.9141
#    ap;average=macro: 0.9448
#    ap;average=weighted: 0.9735
# Модель xgboost сохранена в /home/gleb/models/20250411_000739_0.9147_xgboost_multi.pickle
#
# Лучшая модель по метрике accuracy: xgboost
# Значение метрики: 0.91472

# %% [markdown]
# # Regression

# %%
modelling = SOTAModels('allstate-claims-severity.yaml')
trained_models, metrics_results = modelling.train_models()
# Out:
# Splitting data ...
# Data split done: train shape: (112990, 132), test shape: (37664, 132), valid shape: (37664, 132)
# ----------
# Обучение модели: random_forest на 3 фолдах, тип задачи: regression
# Fold 1: mae: 1238.6472
# Fold 2: mae: 1253.1366
# Fold 3: mae: 1255.9391
# Метрики на тестовых данных (holdout):
#    mae: 1233.0637
#    rmse: 1905.3645
#    r2: 0.5551
#    mape: 0.6388
# Метрики на валидационных данных (out-of-time):
#    mae: 1251.1021
#    rmse: 2041.9669
#    r2: 0.5330
#    mape: 0.6526
# Модель random_forest сохранена в /home/gleb/models/20250411_001958_1251.1021_random_forest_regression.pickle
#
# ----------
# Обучение модели: catboost на 3 фолдах, тип задачи: regression
# Fold 1: mae: 1177.4194
# Fold 2: mae: 1198.8923
# Fold 3: mae: 1199.2331
# Метрики на тестовых данных (holdout):
#    mae: 1179.2120
#    rmse: 1862.3984
#    r2: 0.5749
#    mape: 0.5834
# Метрики на валидационных данных (out-of-time):
#    mae: 1201.9227
#    rmse: 2002.9129
#    r2: 0.5507
#    mape: 0.6006
# Модель catboost сохранена в /home/gleb/models/20250411_002725_1201.9227_catboost_regression.pickle
#
# ----------
# Обучение модели: lightgbm на 3 фолдах, тип задачи: regression
# [LightGBM] [Warning] Accuracy may be bad since you didn't set num_leaves and 2^max_depth > num_leaves
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [200]	valid_0's rmse: 1852.64
# Fold 1: mae: 1186.1938
# [LightGBM] [Warning] Accuracy may be bad since you didn't set num_leaves and 2^max_depth > num_leaves
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [230]	valid_0's rmse: 1911.33
# Fold 2: mae: 1200.5123
# [LightGBM] [Warning] Accuracy may be bad since you didn't set num_leaves and 2^max_depth > num_leaves
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [139]	valid_0's rmse: 1911.82
# Fold 3: mae: 1205.7997
# Метрики на тестовых данных (holdout):
#    mae: 1180.2500
#    rmse: 1866.6401
#    r2: 0.5730
#    mape: 0.5843
# Метрики на валидационных данных (out-of-time):
#    mae: 1199.8350
#    rmse: 2002.9085
#    r2: 0.5507
#    mape: 0.6011
# Модель lightgbm сохранена в /home/gleb/models/20250411_002735_1199.8350_lightgbm_regression.pickle
#
# ----------
# Обучение модели: xgboost на 3 фолдах, тип задачи: regression
# Fold 1: mae: 1206.4905
# Fold 2: mae: 1227.1905
# Fold 3: mae: 1231.7893
# Метрики на тестовых данных (holdout):
#    mae: 1181.6884
#    rmse: 1868.0959
#    r2: 0.5723
#    mape: 0.5841
# Метрики на валидационных данных (out-of-time):
#    mae: 1204.1231
#    rmse: 2012.8762
#    r2: 0.5462
#    mape: 0.6007
# Модель xgboost сохранена в /home/gleb/models/20250411_002743_1204.1231_xgboost_regression.pickle
#
# Лучшая модель по метрике mae: lightgbm
# Значение метрики: 1199.834990320492

# %%
# Финальная сводка по всем моделям
# Сортировка метрик с параметрами
# Соранять модели в zip-архиве
