# %%
import sys
import os
import pandas as pd
import numpy as np
pd.options.display.max_columns = None

sys.path.append('../')
from modeling import SOTAModels
from models.catboost_model import CatBoostModel

# %%
data_file = '../dataset/home-credit-default-risk/train.parquet'
data = pd.read_parquet(data_file)

# %%
modelling = SOTAModels('binari_config.yaml')
modelling.train_models()
# Out:
# Обучение модели: catboost
# Обучение на фолде 1/3 (binary)
# Обучение CatBoost (binary) - фолд 1/3
# Обучение на фолде 2/3 (binary)
# Обучение CatBoost (binary) - фолд 2/3
# Обучение на фолде 3/3 (binary)
# Обучение CatBoost (binary) - фолд 3/3
#   f1: 0.0849
#   roc_auc: 0.7805
#   recall@k: 0.3672
#   precision@k: 0.2964
#   ap: 0.2702
#   ap: 0.2702
#   f1: 0.0849
# Результаты модели catboost: {'f1': 0.08486878838637632, 'roc_auc': 0.7804909442596754, 'recall@k': 0.3671701913393756, 'precision@k': 0.2964227642276423, 'ap': 0.27017949388349893}
# Лучшая модель по метрике roc_auc: catboost
# Значение метрики: 0.7804909442596754
# ({'catboost': <models.catboost_model.CatBoostModel at 0x7fb2da8356d0>},
#  {'catboost': {'f1': 0.08486878838637632,
#    'roc_auc': 0.7804909442596754,
#    'recall@k': 0.3671701913393756,
#    'precision@k': 0.2964227642276423,
#    'ap': 0.27017949388349893}})
