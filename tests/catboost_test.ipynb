# %%
import sys
import pandas as pd
import numpy as np
pd.options.display.max_columns = None

sys.path.append('../')
from modeling import SOTAModels

# %% [markdown]
# # Binary

# %%
# data = pd.read_parquet('/www/dslib/spark_sota_modeling/dataset/home-credit-default-risk/train.parquet')
# data.info(max_cols=1000, show_counts=True)
# data.columns[~np.isfinite(data.values).all(axis=0)].tolist()

# %%
modelling = SOTAModels('home-credit-default-risk.yaml')
trained_models, metrics_results = modelling.train_models()
# Out:
# Splitting data ...
# Data split done: train shape: (184506, 464), test shape: (61503, 464), valid shape: (61502, 464)
# Sampling data ...
# Data sampled: train shape: (29790, 464), valid shape: (61502, 464)
# ----------
# Обучение модели: xgboost на 3 фолдах, тип задачи: binary
# Fold 1: roc_auc: 0.7511
# Fold 2: roc_auc: 0.7541
# Fold 3: roc_auc: 0.7491
# Метрики на тестовых данных (holdout):
#    f1: 0.2777
#    roc_auc: 0.7726
#    recall@k;k=0.1: 0.3561
#    precision@k;k=0.1: 0.2875
#    ap;average=micro: 0.2588
#    ap;average=weighted: 0.2588
#    f1;average=binary: 0.2777
# Calibrating ... done
# Метрики на валидационных данных (out-of-time):
#    f1: 0.0544
#    roc_auc: 0.7701
#    recall@k;k=0.1: 0.3450
#    precision@k;k=0.1: 0.2785
#    ap;average=micro: 0.2465
#    ap;average=weighted: 0.2465
#    f1;average=binary: 0.0544
# Модель xgboost сохранена в /home/gleb/models/20250410_220258_0.7701_xgboost_binary.pickle
#
# ----------
# Обучение модели: lightgbm на 3 фолдах, тип задачи: binary
# Fold 1: roc_auc: 0.7704
# Fold 2: roc_auc: 0.7697
# Fold 3: roc_auc: 0.7637
# Метрики на тестовых данных (holdout):
#    f1: 0.2811
#    roc_auc: 0.7767
#    recall@k;k=0.1: 0.3682
#    precision@k;k=0.1: 0.2972
#    ap;average=micro: 0.2665
#    ap;average=weighted: 0.2665
#    f1;average=binary: 0.2811
# Calibrating ... done
# Метрики на валидационных данных (out-of-time):
#    f1: 0.0451
#    roc_auc: 0.7762
#    recall@k;k=0.1: 0.3567
#    precision@k;k=0.1: 0.2880
#    ap;average=micro: 0.2551
#    ap;average=weighted: 0.2551
#    f1;average=binary: 0.0451
# Модель lightgbm сохранена в /home/gleb/models/20250410_220318_0.7762_lightgbm_binary.pickle
#
# ----------
# Обучение модели: catboost на 3 фолдах, тип задачи: binary
# Fold 1: roc_auc: 0.7784
# Fold 2: roc_auc: 0.7753
# Fold 3: roc_auc: 0.7697
# Метрики на тестовых данных (holdout):
#    f1: 0.2848
#    roc_auc: 0.7803
#    recall@k;k=0.1: 0.3702
#    precision@k;k=0.1: 0.2989
#    ap;average=micro: 0.2738
#    ap;average=weighted: 0.2738
#    f1;average=binary: 0.2848
# Calibrating ... done
# Метрики на валидационных данных (out-of-time):
#    f1: 0.0674
#    roc_auc: 0.7765
#    recall@k;k=0.1: 0.3579
#    precision@k;k=0.1: 0.2889
#    ap;average=micro: 0.2583
#    ap;average=weighted: 0.2583
#    f1;average=binary: 0.0674
# Модель catboost сохранена в /home/gleb/models/20250410_220532_0.7765_catboost_binary.pickle
#
# Лучшая модель по метрике roc_auc: catboost
# Значение метрики: 0.7764633239938533

# %% [markdown]
# # Multi

# %%
# data = pd.read_parquet('/www/dslib/spark_sota_modeling/dataset/forest-cover-type/train.parquet')

# %%
modelling = SOTAModels('forest-cover-type.yaml')
trained_models, metrics_results = modelling.train_models()
# Out:
# Splitting data ...
# Data split done: train shape: (348606, 55), test shape: (116203, 55), valid shape: (116203, 55)
# Sampling data ...
# Data sampled: train shape: (100000, 55), valid shape: (100000, 55)
# ----------
# Обучение модели: xgboost на 3 фолдах, тип задачи: multi
# Fold 1: accuracy: 0.8584
# Fold 2: accuracy: 0.8582
# Fold 3: accuracy: 0.8571
# Метрики на тестовых данных (holdout):
#    accuracy: 0.8625
#    f1;average=weighted: 0.8614
#    ap;average=macro: 0.9127
#    ap;average=weighted: 0.9394
# Метрики на валидационных данных (out-of-time):
#    accuracy: 0.8614
#    f1;average=weighted: 0.8602
#    ap;average=macro: 0.9104
#    ap;average=weighted: 0.9392
# Модель xgboost сохранена в /home/gleb/models/20250410_220557_0.8614_xgboost_multi.pickle
#
# ----------
# Обучение модели: lightgbm на 3 фолдах, тип задачи: multi
# Fold 1: accuracy: 0.8297
# Fold 2: accuracy: 0.8315
# Fold 3: accuracy: 0.8258
# Метрики на тестовых данных (holdout):
#    accuracy: 0.8290
#    f1;average=weighted: 0.8275
#    ap;average=macro: 0.8890
#    ap;average=weighted: 0.9136
# Метрики на валидационных данных (out-of-time):
#    accuracy: 0.8273
#    f1;average=weighted: 0.8258
#    ap;average=macro: 0.8872
#    ap;average=weighted: 0.9136
# Модель lightgbm сохранена в /home/gleb/models/20250410_220617_0.8273_lightgbm_multi.pickle
#
# ----------
# Обучение модели: catboost на 3 фолдах, тип задачи: multi
# Fold 1: accuracy: 0.8712
# Fold 2: accuracy: 0.8705
# Fold 3: accuracy: 0.8653
# Метрики на тестовых данных (holdout):
#    accuracy: 0.8719
#    f1;average=weighted: 0.8707
#    ap;average=macro: 0.9073
#    ap;average=weighted: 0.9444
# Метрики на валидационных данных (out-of-time):
#    accuracy: 0.8707
#    f1;average=weighted: 0.8695
#    ap;average=macro: 0.9060
#    ap;average=weighted: 0.9439
# Модель catboost сохранена в /home/gleb/models/20250410_220726_0.8707_catboost_multi.pickle
#
# Лучшая модель по метрике accuracy: catboost
# Значение метрики: 0.87074

# %% [markdown]
# # Regression

# %%
modelling = SOTAModels('allstate-claims-severity.yaml')
trained_models, metrics_results = modelling.train_models()
# Out:
# Splitting data ...
# Data split done: train shape: (112990, 132), test shape: (37664, 132), valid shape: (37664, 132)
# ----------
# Обучение модели: xgboost на 3 фолдах, тип задачи: regression
# Fold 1: mae: 1209.7636
# Fold 2: mae: 1226.5479
# Fold 3: mae: 1222.9351
# Метрики на тестовых данных (holdout):
#    mae: 1181.2177
#    rmse: 1855.3773
#    r2: 0.5781
#    mape: 0.5819
# Метрики на валидационных данных (out-of-time):
#    mae: 1205.1727
#    rmse: 2000.6964
#    r2: 0.5517
#    mape: 0.6000
# Модель xgboost сохранена в /home/gleb/models/20250410_220738_1205.1727_xgboost_regression.pickle
#
# ----------
# Обучение модели: lightgbm на 3 фолдах, тип задачи: regression
# Fold 1: mae: 1192.1846
# Fold 2: mae: 1207.3554
# Fold 3: mae: 1209.5953
# Метрики на тестовых данных (holdout):
#    mae: 1187.1593
#    rmse: 1869.0968
#    r2: 0.5719
#    mape: 0.5923
# Метрики на валидационных данных (out-of-time):
#    mae: 1209.6753
#    rmse: 2017.6540
#    r2: 0.5440
#    mape: 0.6102
# Модель lightgbm сохранена в /home/gleb/models/20250410_220743_1209.6753_lightgbm_regression.pickle
#
# ----------
# Обучение модели: catboost на 3 фолдах, тип задачи: regression
# Fold 1: mae: 1179.1963
# Fold 2: mae: 1194.0059
# Fold 3: mae: 1195.3999
# Метрики на тестовых данных (holdout):
#    mae: 1175.6600
#    rmse: 1858.2057
#    r2: 0.5768
#    mape: 0.5818
# Метрики на валидационных данных (out-of-time):
#    mae: 1197.0556
#    rmse: 1994.9674
#    r2: 0.5542
#    mape: 0.5979
# Модель catboost сохранена в /home/gleb/models/20250410_221425_1197.0556_catboost_regression.pickle
#
# Лучшая модель по метрике mae: catboost
# Значение метрики: 1197.055634882255

# %%
# Переопределение гиперпараметров в конфиге
