# %%
import sys
import pandas as pd
import numpy as np
pd.options.display.max_columns = None

sys.path.append('../')
from modeling import SOTAModels

# %% [markdown]
# # Binary

# %%
modelling = SOTAModels('home-credit-default-risk.yaml')
trained_models, metrics_results = modelling.train_models()
# Out:
# Splitting data ...
# Data split done: train shape: (184506, 464), test shape: (61503, 464), valid shape: (61502, 464)
# Sampling data ...
# Data sampled: train shape: (29790, 464), valid shape: (61502, 464)
# ----------
# Обучение модели: lightautoml на 1 фолдах, тип задачи: binary
# Calibrating ... done
# Метрики на валидационных данных (out-of-time):
#    f1: 0.2024
#    roc_auc: 0.7828
#    recall@k;k=0.1: 0.3680
#    precision@k;k=0.1: 0.2971
#    ap;average=micro: 0.2707
#    ap;average=weighted: 0.2707
#    f1;average=binary: 0.2024
# Модель lightautoml сохранена в /home/gleb/models/20250412_100646_0.7828_lightautoml_binary.pickle
#
# ----------
# Обучение модели: random_forest на 3 фолдах, тип задачи: binary
# Fold 1: roc_auc: 0.7506
# Fold 2: roc_auc: 0.7482
# Fold 3: roc_auc: 0.7487
# Calibrating ... done
# Метрики на валидационных данных (out-of-time):
#    f1: 0.0111
#    roc_auc: 0.7537
#    recall@k;k=0.1: 0.3190
#    precision@k;k=0.1: 0.2576
#    ap;average=micro: 0.2179
#    ap;average=weighted: 0.2179
#    f1;average=binary: 0.0111
# Модель random_forest сохранена в /home/gleb/models/20250412_100712_0.7537_random_forest_binary.pickle
#
# ----------
# Обучение модели: catboost на 3 фолдах, тип задачи: binary
# Fold 1: roc_auc: 0.7767
# Fold 2: roc_auc: 0.7763
# Fold 3: roc_auc: 0.7698
# Calibrating ... done
# Метрики на валидационных данных (out-of-time):
#    f1: 0.0636
#    roc_auc: 0.7765
#    recall@k;k=0.1: 0.3557
#    precision@k;k=0.1: 0.2872
#    ap;average=micro: 0.2563
#    ap;average=weighted: 0.2563
#    f1;average=binary: 0.0636
# Модель catboost сохранена в /home/gleb/models/20250412_100837_0.7765_catboost_binary.pickle
#
# ----------
# Обучение модели: lightgbm на 3 фолдах, тип задачи: binary
# Fold 1: roc_auc: 0.7706
# Fold 2: roc_auc: 0.7704
# Fold 3: roc_auc: 0.7649
# Calibrating ... done
# Метрики на валидационных данных (out-of-time):
#    f1: 0.0402
#    roc_auc: 0.7762
#    recall@k;k=0.1: 0.3585
#    precision@k;k=0.1: 0.2894
#    ap;average=micro: 0.2555
#    ap;average=weighted: 0.2555
#    f1;average=binary: 0.0402
# Модель lightgbm сохранена в /home/gleb/models/20250412_100854_0.7762_lightgbm_binary.pickle
#
# ----------
# Обучение модели: xgboost на 3 фолдах, тип задачи: binary
# Fold 1: roc_auc: 0.7567
# Fold 2: roc_auc: 0.7594
# Fold 3: roc_auc: 0.7514
# Calibrating ... done
# Метрики на валидационных данных (out-of-time):
#    f1: 0.0504
#    roc_auc: 0.7693
#    recall@k;k=0.1: 0.3396
#    precision@k;k=0.1: 0.2741
#    ap;average=micro: 0.2452
#    ap;average=weighted: 0.2452
#    f1;average=binary: 0.0504
# Модель xgboost сохранена в /home/gleb/models/20250412_100915_0.7693_xgboost_binary.pickle
#
# Лучшая модель по метрике roc_auc: lightautoml
# Значение метрики: 0.7828042721748885
#
# Результаты моделей:
# +---------------+-----------+--------------------+-----------------------+--------+---------------------+---------------------+------------------+
# |        Модель |   roc_auc |   ap;average=micro |   ap;average=weighted |     f1 |   f1;average=binary |   precision@k;k=0.1 |   recall@k;k=0.1 |
# +===============+===========+====================+=======================+========+=====================+=====================+==================+
# |   lightautoml |    0.7828 |             0.2707 |                0.2707 | 0.2024 |              0.2024 |              0.2971 |           0.368  |
# +---------------+-----------+--------------------+-----------------------+--------+---------------------+---------------------+------------------+
# |      catboost |    0.7765 |             0.2563 |                0.2563 | 0.0636 |              0.0636 |              0.2872 |           0.3557 |
# +---------------+-----------+--------------------+-----------------------+--------+---------------------+---------------------+------------------+
# |      lightgbm |    0.7762 |             0.2555 |                0.2555 | 0.0402 |              0.0402 |              0.2894 |           0.3585 |
# +---------------+-----------+--------------------+-----------------------+--------+---------------------+---------------------+------------------+
# |       xgboost |    0.7693 |             0.2452 |                0.2452 | 0.0504 |              0.0504 |              0.2741 |           0.3396 |
# +---------------+-----------+--------------------+-----------------------+--------+---------------------+---------------------+------------------+
# | random_forest |    0.7537 |             0.2179 |                0.2179 | 0.0111 |              0.0111 |              0.2576 |           0.319  |
# +---------------+-----------+--------------------+-----------------------+--------+---------------------+---------------------+------------------+

# %% [markdown]
# # Multi

# %%
modelling = SOTAModels('forest-cover-type.yaml')
trained_models, metrics_results = modelling.train_models()
# Out:
# Splitting data ...
# Data split done: train shape: (348606, 55), test shape: (116203, 55), valid shape: (116203, 55)
# Sampling data ...
# Data sampled: train shape: (100000, 55), valid shape: (100000, 55)
# ----------
# Обучение модели: catboost на 3 фолдах, тип задачи: multiclass
# Fold 1: f1;average=micro: 0.8716
# Fold 2: f1;average=micro: 0.8708
# Fold 3: f1;average=micro: 0.8688
# Метрики на валидационных данных (out-of-time):
#    f1;average=micro: 0.8707
#    accuracy: 0.8707
#    f1;average=weighted: 0.8695
#    ap;average=macro: 0.9056
#    ap;average=weighted: 0.9439
# Модель catboost сохранена в /home/gleb/models/20250412_101032_0.8707_catboost_multiclass.pickle
#
# ----------
# Обучение модели: lightgbm на 3 фолдах, тип задачи: multiclass
# Fold 1: f1;average=micro: 0.9100
# Fold 2: f1;average=micro: 0.9092
# Fold 3: f1;average=micro: 0.9060
# Метрики на валидационных данных (out-of-time):
#    f1;average=micro: 0.9110
#    accuracy: 0.9110
#    f1;average=weighted: 0.9105
#    ap;average=macro: 0.9462
#    ap;average=weighted: 0.9711
# Модель lightgbm сохранена в /home/gleb/models/20250412_101317_0.9110_lightgbm_multiclass.pickle
#
# ----------
# Обучение модели: xgboost на 3 фолдах, тип задачи: multiclass
# Fold 1: f1;average=micro: 0.9153

# %% [markdown]
# # Multi 2 (okved)

# %%
# modelling = SOTAModels('okved.yaml')
# trained_models, metrics_results = modelling.train_models()

# %% [markdown]
# # Regression

# %%
modelling = SOTAModels('allstate-claims-severity.yaml')
trained_models, metrics_results = modelling.train_models()

# %%
# Финальная сводка по всем моделям
# Соранять модели в zip-архиве
# Заголовок для модели
# Сохранение состояния модели
