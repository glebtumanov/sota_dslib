# %%
import sys
import pandas as pd
import numpy as np
pd.options.display.max_columns = None

sys.path.append('../')
from modeling import SOTAModels

# %% [markdown]
# # Binary

# %%
modelling = SOTAModels('home-credit-default-risk.yaml')
trained_models, metrics_results = modelling.train_models()
# Out:
# Splitting data ...
# Data split done: train shape: (184506, 464), test shape: (61503, 464), valid shape: (61502, 464)
# Sampling data ...
# Data sampled: train shape: (29790, 464), valid shape: (61502, 464)
# ----------
# Обучение модели: lightautoml на 1 фолдах, тип задачи: binary
# Calibrating ... done
# Метрики на валидационных данных (out-of-time):
#    roc_auc: 0.7828
#    f1@k;k=0.1: 0.3284
#    recall@k;k=0.1: 0.3676
#    precision@k;k=0.1: 0.2967
#    ap: 0.2707
#
# ----------
# Обучение модели: random_forest на 3 фолдах, тип задачи: binary
# Fold 1: roc_auc: 0.7506
# Fold 2: roc_auc: 0.7482
# Fold 3: roc_auc: 0.7487
# Calibrating ... done
# Метрики на валидационных данных (out-of-time):
#    roc_auc: 0.7537
#    f1@k;k=0.1: 0.2850
#    recall@k;k=0.1: 0.3190
#    precision@k;k=0.1: 0.2576
#    ap: 0.2179
#
# ----------
# Обучение модели: catboost на 3 фолдах, тип задачи: binary
# Fold 1: roc_auc: 0.7767
# Fold 2: roc_auc: 0.7763
# Fold 3: roc_auc: 0.7698
# Calibrating ... done
# Метрики на валидационных данных (out-of-time):
#    roc_auc: 0.7765
#    f1@k;k=0.1: 0.3178
#    recall@k;k=0.1: 0.3557
#    precision@k;k=0.1: 0.2872
#    ap: 0.2563
#
# ----------
# Обучение модели: lightgbm на 3 фолдах, тип задачи: binary
# Fold 1: roc_auc: 0.7706
# Fold 2: roc_auc: 0.7704
# Fold 3: roc_auc: 0.7649
# Calibrating ... done
# Метрики на валидационных данных (out-of-time):
#    roc_auc: 0.7762
#    f1@k;k=0.1: 0.3203
#    recall@k;k=0.1: 0.3585
#    precision@k;k=0.1: 0.2894
#    ap: 0.2555
#
# ----------
# Обучение модели: xgboost на 3 фолдах, тип задачи: binary
# Fold 1: roc_auc: 0.7567
# Fold 2: roc_auc: 0.7594
# Fold 3: roc_auc: 0.7514
# Calibrating ... done
# Метрики на валидационных данных (out-of-time):
#    roc_auc: 0.7693
#    f1@k;k=0.1: 0.3034
#    recall@k;k=0.1: 0.3396
#    precision@k;k=0.1: 0.2741
#    ap: 0.2452
#
#
# Результаты моделей:
# +---------------+-----------+--------+--------------+---------------------+------------------+
# |        Модель |   roc_auc |     ap |   f1@k;k=0.1 |   precision@k;k=0.1 |   recall@k;k=0.1 |
# +===============+===========+========+==============+=====================+==================+
# |   lightautoml |    0.7828 | 0.2707 |       0.3284 |              0.2967 |           0.3676 |
# +---------------+-----------+--------+--------------+---------------------+------------------+
# |      catboost |    0.7765 | 0.2563 |       0.3178 |              0.2872 |           0.3557 |
# +---------------+-----------+--------+--------------+---------------------+------------------+
# |      lightgbm |    0.7762 | 0.2555 |       0.3203 |              0.2894 |           0.3585 |
# +---------------+-----------+--------+--------------+---------------------+------------------+
# |       xgboost |    0.7693 | 0.2452 |       0.3034 |              0.2741 |           0.3396 |
# +---------------+-----------+--------+--------------+---------------------+------------------+
# | random_forest |    0.7537 | 0.2179 |       0.285  |              0.2576 |           0.319  |
# +---------------+-----------+--------+--------------+---------------------+------------------+
#
# Лучшая модель по метрике roc_auc: lightautoml
# Значение метрики: 0.7827865418935075
# Лучшая модель lightautoml сохранена в /home/gleb/models/home-credit-default-risk/20250412_0.7828_binary_lightautoml.zip

# %% [markdown]
# # Multi

# %%
modelling = SOTAModels('forest-cover-type.yaml')
trained_models, metrics_results = modelling.train_models()
# Out:
# Splitting data ...
# Data split done: train shape: (348606, 55), test shape: (116203, 55), valid shape: (116203, 55)
# Sampling data ...
# Data sampled: train shape: (100000, 55), valid shape: (100000, 55)
# ----------
# Обучение модели: catboost на 3 фолдах, тип задачи: multiclass
# Fold 1: accuracy: 0.8716
# Fold 2: accuracy: 0.8708
# Fold 3: accuracy: 0.8688
# Метрики на валидационных данных (out-of-time):
#    accuracy: 0.8707
#    f1;average=weighted: 0.8695
#    ap;average=macro: 0.9056
#    roc_auc;average=macro;multi_class=ovo: 0.9860
#
# ----------
# Обучение модели: lightgbm на 3 фолдах, тип задачи: multiclass
# Fold 1: accuracy: 0.9100
# Fold 2: accuracy: 0.9092
# Fold 3: accuracy: 0.9060
# Метрики на валидационных данных (out-of-time):
#    accuracy: 0.9110
#    f1;average=weighted: 0.9105
#    ap;average=macro: 0.9462
#    roc_auc;average=macro;multi_class=ovo: 0.9916
#
# ----------
# Обучение модели: xgboost на 3 фолдах, тип задачи: multiclass
# Fold 1: accuracy: 0.9153
# Fold 2: accuracy: 0.9142
# Fold 3: accuracy: 0.9131
# Метрики на валидационных данных (out-of-time):
#    accuracy: 0.9192
#    f1;average=weighted: 0.9187
#    ap;average=macro: 0.9450
#    roc_auc;average=macro;multi_class=ovo: 0.9922
#
# ----------
# Обучение модели: random_forest на 3 фолдах, тип задачи: multiclass
# Fold 1: accuracy: 0.8988
# Fold 2: accuracy: 0.8994
# Fold 3: accuracy: 0.8970
# Метрики на валидационных данных (out-of-time):
#    accuracy: 0.8984
#    f1;average=weighted: 0.8969
#    ap;average=macro: 0.9282
#    roc_auc;average=macro;multi_class=ovo: 0.9893
#
# ----------
# Обучение модели: lightautoml на 1 фолдах, тип задачи: multiclass
# Метрики на валидационных данных (out-of-time):
#    accuracy: 0.9456
#    f1;average=weighted: 0.9455
#    ap;average=macro: 0.9649
#    roc_auc;average=macro;multi_class=ovo: 0.9959
#
#
# Результаты моделей:
# +---------------+------------+--------------------+-----------------------+-----------------------------------------+
# |        Модель |   accuracy |   ap;average=macro |   f1;average=weighted |   roc_auc;average=macro;multi_class=ovo |
# +===============+============+====================+=======================+=========================================+
# |   lightautoml |     0.9456 |             0.9649 |                0.9455 |                                  0.9959 |
# +---------------+------------+--------------------+-----------------------+-----------------------------------------+
# |       xgboost |     0.9192 |             0.945  |                0.9187 |                                  0.9922 |
# +---------------+------------+--------------------+-----------------------+-----------------------------------------+
# |      lightgbm |     0.911  |             0.9462 |                0.9105 |                                  0.9916 |
# +---------------+------------+--------------------+-----------------------+-----------------------------------------+
# | random_forest |     0.8984 |             0.9282 |                0.8969 |                                  0.9893 |
# +---------------+------------+--------------------+-----------------------+-----------------------------------------+
# |      catboost |     0.8707 |             0.9056 |                0.8695 |                                  0.986  |
# +---------------+------------+--------------------+-----------------------+-----------------------------------------+
#
# Лучшая модель по метрике accuracy: lightautoml
# Значение метрики: 0.94558
# Лучшая модель lightautoml сохранена в /home/gleb/models/forest-cover-type/20250412_0.9456_multiclass_lightautoml.zip

# %% [markdown]
# # Multi 2 (okved)

# %%
# modelling = SOTAModels('okved.yaml')
# trained_models, metrics_results = modelling.train_models()

# %% [markdown]
# # Regression

# %%
modelling = SOTAModels('allstate-claims-severity.yaml')
trained_models, metrics_results = modelling.train_models()
# Out:
# Splitting data ...
# Data split done: train shape: (112990, 132), test shape: (37664, 132), valid shape: (37664, 132)
# ----------
# Обучение модели: lightautoml на 1 фолдах, тип задачи: regression
# Метрики на валидационных данных (out-of-time):
#    mae: 1193.7020
#    rmse: 1990.9766
#    r2: 0.5560
#    mape: 0.6013
#
# ----------
# Обучение модели: random_forest на 3 фолдах, тип задачи: regression
# Fold 1: mae: 1247.0587
# Fold 2: mae: 1263.0667
# Fold 3: mae: 1264.9402
# Метрики на валидационных данных (out-of-time):
#    mae: 1252.1681
#    rmse: 2044.5924
#    r2: 0.5318
#    mape: 0.6497
#
# ----------
# Обучение модели: catboost на 3 фолдах, тип задачи: regression
# Fold 1: mae: 1175.6366
# Fold 2: mae: 1194.1152
# Fold 3: mae: 1193.3070
# Метрики на валидационных данных (out-of-time):
#    mae: 1196.6012
#    rmse: 1996.6909
#    r2: 0.5535
#    mape: 0.5961
#
# ----------
# Обучение модели: lightgbm на 3 фолдах, тип задачи: regression
# Fold 1: mae: 1189.3723
# Fold 2: mae: 1205.2067
# Fold 3: mae: 1206.8369
# Метрики на валидационных данных (out-of-time):
#    mae: 1205.5933
#    rmse: 2009.5579
#    r2: 0.5477
#    mape: 0.6055
#
# ----------
# Обучение модели: xgboost на 3 фолдах, тип задачи: regression
# Fold 1: mae: 1205.2043
# Fold 2: mae: 1219.8673
# Fold 3: mae: 1220.3039
# Метрики на валидационных данных (out-of-time):
#    mae: 1207.8378
#    rmse: 1999.3346
#    r2: 0.5523
#    mape: 0.6049
#
#
# Результаты моделей:
# +---------------+---------+--------+--------+---------+
# |        Модель |     mae |   mape |     r2 |    rmse |
# +===============+=========+========+========+=========+
# |   lightautoml | 1193.7  | 0.6013 | 0.556  | 1990.98 |
# +---------------+---------+--------+--------+---------+
# |      catboost | 1196.6  | 0.5961 | 0.5535 | 1996.69 |
# +---------------+---------+--------+--------+---------+
# |      lightgbm | 1205.59 | 0.6055 | 0.5477 | 2009.56 |
# +---------------+---------+--------+--------+---------+
# |       xgboost | 1207.84 | 0.6049 | 0.5523 | 1999.33 |
# +---------------+---------+--------+--------+---------+
# | random_forest | 1252.17 | 0.6497 | 0.5318 | 2044.59 |
# +---------------+---------+--------+--------+---------+
#
# Лучшая модель по метрике mae: lightautoml
# Значение метрики: 1193.7020100292962
# Лучшая модель lightautoml сохранена в /home/gleb/models/allstate-claims-severity/20250412_1193.7020_regression_lightautoml.zip

# %%
# Заголовок для модели
# Сохранение состояния модели
