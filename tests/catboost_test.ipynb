# %%
import sys
import pandas as pd
import numpy as np
pd.options.display.max_columns = None

sys.path.append('../')
from modeling import SOTAModels

# %% [markdown]
# # Binary

# %%
modelling = SOTAModels('home-credit-default-risk.yaml')
trained_models, metrics_results = modelling.train_models()
# Out:
# {'lightautoml': 1}
# Splitting data ...
# Data split done: train shape: (184506, 464), test shape: (61503, 464), valid shape: (61502, 464)
# Sampling data ...
# Data sampled: train shape: (29790, 464), valid shape: (61502, 464)
# ----------
# Обучение модели: lightautoml на 1 фолдах, тип задачи: binary
# Calibrating ... done
# Метрики на валидационных данных (out-of-time):
#    f1: 0.2030
#    roc_auc: 0.7828
#    recall@k;k=0.1: 0.3678
#    precision@k;k=0.1: 0.2969
#    ap;average=micro: 0.2707
#    ap;average=weighted: 0.2707
#    f1;average=binary: 0.2030
# Модель lightautoml сохранена в /home/gleb/models/20250411_213239_0.7828_lightautoml_binary.pickle
#
# Лучшая модель по метрике roc_auc: lightautoml
# Значение метрики: 0.7827811964470114

# %% [markdown]
# # Multi

# %%
modelling = SOTAModels('forest-cover-type.yaml')
trained_models, metrics_results = modelling.train_models()
# Out:
# {'lightautoml': 1}
# Splitting data ...
# Data split done: train shape: (348606, 55), test shape: (116203, 55), valid shape: (116203, 55)
# Sampling data ...
# Data sampled: train shape: (100000, 55), valid shape: (100000, 55)
# ----------
# Обучение модели: lightautoml на 1 фолдах, тип задачи: multi
# Метрики на валидационных данных (out-of-time):
#    accuracy: 0.9457
#    f1;average=weighted: 0.9456
#    ap;average=macro: 0.9649
#    ap;average=weighted: 0.9874
# Модель lightautoml сохранена в /home/gleb/models/20250411_223315_0.9457_lightautoml_multi.pickle
#
# Лучшая модель по метрике accuracy: lightautoml
# Значение метрики: 0.94572

# %% [markdown]
# # Multi 2 (okved)

# %%
modelling = SOTAModels('okved.yaml')
trained_models, metrics_results = modelling.train_models()
# Out:
# Splitting data ...
# Data split done: train shape: (129132, 607), test shape: (32283, 607), valid shape: (78654, 607)
# Sampling data ...
# Data sampled: train shape: (100000, 607), valid shape: (78654, 607)
# ----------
# Обучение модели: lightautoml на 1 фолдах, тип задачи: multi

# %% [markdown]
# # Regression

# %%
modelling = SOTAModels('allstate-claims-severity.yaml')
trained_models, metrics_results = modelling.train_models()
# Out:
# Splitting data ...
# Data split done: train shape: (112990, 132), test shape: (37664, 132), valid shape: (37664, 132)
# ----------
# Обучение модели: lightautoml на 1 фолдах, тип задачи: regression
# Метрики на валидационных данных (out-of-time):
#    mae: 1193.7020
#    rmse: 1990.9766
#    r2: 0.5560
#    mape: 0.6013
# Модель lightautoml сохранена в /home/gleb/models/20250412_003940_1193.7020_lightautoml_regression.pickle
#
# Лучшая модель по метрике mae: lightautoml
# Значение метрики: 1193.7020100292962

# %%
# Финальная сводка по всем моделям
# Сортировка метрик с параметрами
# Соранять модели в zip-архиве
# Заголовок для модели
# Сохранение состояния модели
